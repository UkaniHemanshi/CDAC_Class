# %% [markdown]
# <center><b><h1>Assignment_3</h1></b></center>

# %% [markdown]
# ### (Diamonds.csv) Analysis

# %% [markdown]
# ### 1. Write a Pandas program to read a csv file from a specified source and print the first 5 rows.

# %%
import pandas as pd
df = pd.read_csv('./DataSet/diamonds.csv')
df.head()
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# ### 2. Write a Pandas program to read a dataset from diamonds DataFrame and modify the default columns values and print the first 6 rows.

# %%
df['priceUpdated'] = df['price'] * 1.10
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z  priceUpdated
# 0      3.98  2.43         358.6
# 1      3.84  2.31         358.6
# 2      4.07  2.31         359.7
# 3      4.23  2.63         367.4
# 4      4.35  2.75         368.5
# ...     ...   ...           ...
# 53935  5.76  3.50        3032.7
# 53936  5.75  3.61        3032.7
# 53937  5.68  3.56        3032.7
# 53938  6.12  3.74        3032.7
# 53939  5.87  3.64        3032.7
#
# [53940 rows x 12 columns]

# %% [markdown]
# ### 3. Write a Pandas program to select a series from diamonds DataFrame. Print the content of the series.

# %%
series = pd.Series(df.iloc[:,3])
series
# Out:
# 0        E
# 1        E
# 2        E
# 3        I
# 4        J
#         ..
# 53935    D
# 53936    D
# 53937    D
# 53938    H
# 53939    D
# Name: color, Length: 53940, dtype: object

# %% [markdown]
# ### 4. Write a Pandas program to create a new 'Quality -color' Series (use bracket notation to define the Series name) of the diamonds DataFrame.

# %%
df['Quality - color'] = df['cut'] + ' - ' + df['color']
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z  priceUpdated Quality - color
# 0      3.98  2.43         358.6       Ideal - E
# 1      3.84  2.31         358.6     Premium - E
# 2      4.07  2.31         359.7        Good - E
# 3      4.23  2.63         367.4     Premium - I
# 4      4.35  2.75         368.5        Good - J
# ...     ...   ...           ...             ...
# 53935  5.76  3.50        3032.7       Ideal - D
# 53936  5.75  3.61        3032.7        Good - D
# 53937  5.68  3.56        3032.7   Very Good - D
# 53938  6.12  3.74        3032.7     Premium - H
# 53939  5.87  3.64        3032.7       Ideal - D
#
# [53940 rows x 13 columns]

# %% [markdown]
# ### 5. Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe.

# %%
df.shape
# Out:
# (53940, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       53940 non-null  int64
#  1   carat            53940 non-null  float64
#  2   cut              53940 non-null  object
#  3   color            53940 non-null  object
#  4   clarity          53940 non-null  object
#  5   depth            53940 non-null  float64
#  6   table            53940 non-null  float64
#  7   price            53940 non-null  int64
#  8   x                53940 non-null  float64
#  9   y                53940 non-null  float64
#  10  z                53940 non-null  float64
#  11  priceUpdated     53940 non-null  float64
#  12  Quality - color  53940 non-null  object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 5.4+ MB

# %% [markdown]
# ### 6. Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe.

# %%
# df1 = df.iloc[:,:].dtypes=="object"
# df1.info()

# Select only 'object' columns
object_columns = df.select_dtypes(include=['object'])

# Summarize the object columns
summary = object_columns.info()

# Display the summary
print(summary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cut              53940 non-null  object
#  1   color            53940 non-null  object
#  2   clarity          53940 non-null  object
#  3   Quality - color  53940 non-null  object
# dtypes: object(4)
# memory usage: 1.6+ MB
# None

# %% [markdown]
# ### 7. Write a Pandas program to rename two of the columns of the diamonds Dataframe.

# %%
df = df.rename(columns={'cut':'cutDiamond','color':'ColorInitial'})

df.head(6)
# Out:
#    Unnamed: 0  carat cutDiamond ColorInitial clarity  depth  table  price  \
# 0           1   0.23      Ideal            E     SI2   61.5   55.0    326
# 1           2   0.21    Premium            E     SI1   59.8   61.0    326
# 2           3   0.23       Good            E     VS1   56.9   65.0    327
# 3           4   0.29    Premium            I     VS2   62.4   58.0    334
# 4           5   0.31       Good            J     SI2   63.3   58.0    335
# 5           6   0.24  Very Good            J    VVS2   62.8   57.0    336
#
#       x     y     z  priceUpdated Quality - color
# 0  3.95  3.98  2.43         358.6       Ideal - E
# 1  3.89  3.84  2.31         358.6     Premium - E
# 2  4.05  4.07  2.31         359.7        Good - E
# 3  4.20  4.23  2.63         367.4     Premium - I
# 4  4.34  4.35  2.75         368.5        Good - J
# 5  3.94  3.96  2.48         369.6   Very Good - J

# %% [markdown]
# ### 8.Write a Pandas program to rename all the columns of the diamonds Dataframe.

# %%
data = df.rename(columns={'cut':'cutDiamond','color':'ColorInitial','carat':'carat24','clarity':'clear'})

data.head(6)
# Out:
#    Unnamed: 0  carat24 cutDiamond ColorInitial clear  depth  table  price  \
# 0           1     0.23      Ideal            E   SI2   61.5   55.0    326
# 1           2     0.21    Premium            E   SI1   59.8   61.0    326
# 2           3     0.23       Good            E   VS1   56.9   65.0    327
# 3           4     0.29    Premium            I   VS2   62.4   58.0    334
# 4           5     0.31       Good            J   SI2   63.3   58.0    335
# 5           6     0.24  Very Good            J  VVS2   62.8   57.0    336
#
#       x     y     z  priceUpdated Quality - color
# 0  3.95  3.98  2.43         358.6       Ideal - E
# 1  3.89  3.84  2.31         358.6     Premium - E
# 2  4.05  4.07  2.31         359.7        Good - E
# 3  4.20  4.23  2.63         367.4     Premium - I
# 4  4.34  4.35  2.75         368.5        Good - J
# 5  3.94  3.96  2.48         369.6   Very Good - J

# %% [markdown]
# ### 9. Write a Pandas program to remove the second column of the diamonds Dataframe.

# %%
df.drop('carat', axis=1)
# Out:
#        Unnamed: 0 cutDiamond ColorInitial clarity  depth  table  price     x  \
# 0               1      Ideal            E     SI2   61.5   55.0    326  3.95
# 1               2    Premium            E     SI1   59.8   61.0    326  3.89
# 2               3       Good            E     VS1   56.9   65.0    327  4.05
# 3               4    Premium            I     VS2   62.4   58.0    334  4.20
# 4               5       Good            J     SI2   63.3   58.0    335  4.34
# ...           ...        ...          ...     ...    ...    ...    ...   ...
# 53935       53936      Ideal            D     SI1   60.8   57.0   2757  5.75
# 53936       53937       Good            D     SI1   63.1   55.0   2757  5.69
# 53937       53938  Very Good            D     SI1   62.8   60.0   2757  5.66
# 53938       53939    Premium            H     SI2   61.0   58.0   2757  6.15
# 53939       53940      Ideal            D     SI2   62.2   55.0   2757  5.83
#
#           y     z  priceUpdated Quality - color
# 0      3.98  2.43         358.6       Ideal - E
# 1      3.84  2.31         358.6     Premium - E
# 2      4.07  2.31         359.7        Good - E
# 3      4.23  2.63         367.4     Premium - I
# 4      4.35  2.75         368.5        Good - J
# ...     ...   ...           ...             ...
# 53935  5.76  3.50        3032.7       Ideal - D
# 53936  5.75  3.61        3032.7        Good - D
# 53937  5.68  3.56        3032.7   Very Good - D
# 53938  6.12  3.74        3032.7     Premium - H
# 53939  5.87  3.64        3032.7       Ideal - D
#
# [53940 rows x 12 columns]

# %%
df
# Out:
#        Unnamed: 0  carat cutDiamond ColorInitial clarity  depth  table  price  \
# 0               1   0.23      Ideal            E     SI2   61.5   55.0    326
# 1               2   0.21    Premium            E     SI1   59.8   61.0    326
# 2               3   0.23       Good            E     VS1   56.9   65.0    327
# 3               4   0.29    Premium            I     VS2   62.4   58.0    334
# 4               5   0.31       Good            J     SI2   63.3   58.0    335
# ...           ...    ...        ...          ...     ...    ...    ...    ...
# 53935       53936   0.72      Ideal            D     SI1   60.8   57.0   2757
# 53936       53937   0.72       Good            D     SI1   63.1   55.0   2757
# 53937       53938   0.70  Very Good            D     SI1   62.8   60.0   2757
# 53938       53939   0.86    Premium            H     SI2   61.0   58.0   2757
# 53939       53940   0.75      Ideal            D     SI2   62.2   55.0   2757
#
#           x     y     z  priceUpdated Quality - color
# 0      3.95  3.98  2.43         358.6       Ideal - E
# 1      3.89  3.84  2.31         358.6     Premium - E
# 2      4.05  4.07  2.31         359.7        Good - E
# 3      4.20  4.23  2.63         367.4     Premium - I
# 4      4.34  4.35  2.75         368.5        Good - J
# ...     ...   ...   ...           ...             ...
# 53935  5.75  5.76  3.50        3032.7       Ideal - D
# 53936  5.69  5.75  3.61        3032.7        Good - D
# 53937  5.66  5.68  3.56        3032.7   Very Good - D
# 53938  6.15  6.12  3.74        3032.7     Premium - H
# 53939  5.83  5.87  3.64        3032.7       Ideal - D
#
# [53940 rows x 13 columns]

# %% [markdown]
# ### 10. Write a Pandas program to remove multiple columns at once of the diamonds Dataframe.

# %%
df.drop(['Unnamed: 0','depth','table'],axis=1,inplace=True)
df
# Out:
#        carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 0       0.23      Ideal            E     SI2    326  3.95  3.98  2.43
# 1       0.21    Premium            E     SI1    326  3.89  3.84  2.31
# 2       0.23       Good            E     VS1    327  4.05  4.07  2.31
# 3       0.29    Premium            I     VS2    334  4.20  4.23  2.63
# 4       0.31       Good            J     SI2    335  4.34  4.35  2.75
# ...      ...        ...          ...     ...    ...   ...   ...   ...
# 53935   0.72      Ideal            D     SI1   2757  5.75  5.76  3.50
# 53936   0.72       Good            D     SI1   2757  5.69  5.75  3.61
# 53937   0.70  Very Good            D     SI1   2757  5.66  5.68  3.56
# 53938   0.86    Premium            H     SI2   2757  6.15  6.12  3.74
# 53939   0.75      Ideal            D     SI2   2757  5.83  5.87  3.64
#
#        priceUpdated Quality - color
# 0             358.6       Ideal - E
# 1             358.6     Premium - E
# 2             359.7        Good - E
# 3             367.4     Premium - I
# 4             368.5        Good - J
# ...             ...             ...
# 53935        3032.7       Ideal - D
# 53936        3032.7        Good - D
# 53937        3032.7   Very Good - D
# 53938        3032.7     Premium - H
# 53939        3032.7       Ideal - D
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### 11. Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe.

# %%
df.drop(df.index[-3:-1],axis=0,inplace=True)

# or df = df[:-2] last two rows
df
# Out:
#        carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 0       0.23      Ideal            E     SI2    326  3.95  3.98  2.43
# 1       0.21    Premium            E     SI1    326  3.89  3.84  2.31
# 2       0.23       Good            E     VS1    327  4.05  4.07  2.31
# 3       0.29    Premium            I     VS2    334  4.20  4.23  2.63
# 4       0.31       Good            J     SI2    335  4.34  4.35  2.75
# ...      ...        ...          ...     ...    ...   ...   ...   ...
# 53933   0.70  Very Good            E     VS2   2757  5.69  5.72  3.49
# 53934   0.72    Premium            D     SI1   2757  5.69  5.73  3.58
# 53935   0.72      Ideal            D     SI1   2757  5.75  5.76  3.50
# 53936   0.72       Good            D     SI1   2757  5.69  5.75  3.61
# 53939   0.75      Ideal            D     SI2   2757  5.83  5.87  3.64
#
#        priceUpdated Quality - color
# 0             358.6       Ideal - E
# 1             358.6     Premium - E
# 2             359.7        Good - E
# 3             367.4     Premium - I
# 4             368.5        Good - J
# ...             ...             ...
# 53933        3032.7   Very Good - E
# 53934        3032.7     Premium - D
# 53935        3032.7       Ideal - D
# 53936        3032.7        Good - D
# 53939        3032.7       Ideal - D
#
# [53938 rows x 10 columns]

# %% [markdown]
# ### 12. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.

# %%
series = df['cutDiamond'].sort_values()
series
# Out:
# 3850          Fair
# 51463         Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: cutDiamond, Length: 53938, dtype: object

# %% [markdown]
# ### 13. Write a Pandas program to sort the 'price' Series in descending order (returns a Series) of diamonds Dataframe.

# %%
series = df['price'].sort_values(ascending= False)
series
# Out:
# 27749    18823
# 27748    18818
# 27747    18806
# 27746    18804
# 27745    18803
#          ...
# 4          335
# 3          334
# 2          327
# 1          326
# 0          326
# Name: price, Length: 53938, dtype: int64

# %% [markdown]
# ### 14. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat'  Series in ascending and descending order.

# %%
df_carat_a = df.sort_values(by='carat')

# %%
df_carat_a
# Out:
#        carat cutDiamond ColorInitial clarity  price      x      y     z  \
# 31593   0.20    Premium            E     VS2    367   3.81   3.78  2.32
# 31597   0.20      Ideal            D     VS2    367   3.81   3.77  2.33
# 31596   0.20    Premium            F     VS2    367   3.73   3.71  2.33
# 31595   0.20      Ideal            E     VS2    367   3.86   3.84  2.30
# 31594   0.20    Premium            E     VS2    367   3.84   3.80  2.28
# ...      ...        ...          ...     ...    ...    ...    ...   ...
# 25998   4.01    Premium            I      I1  15223  10.14  10.10  6.17
# 25999   4.01    Premium            J      I1  15223  10.02   9.94  6.24
# 27130   4.13       Fair            H      I1  17329  10.00   9.85  6.43
# 27630   4.50       Fair            J      I1  18531  10.23  10.16  6.72
# 27415   5.01       Fair            J      I1  18018  10.74  10.54  6.98
#
#        priceUpdated Quality - color
# 31593         403.7     Premium - E
# 31597         403.7       Ideal - D
# 31596         403.7     Premium - F
# 31595         403.7       Ideal - E
# 31594         403.7     Premium - E
# ...             ...             ...
# 25998       16745.3     Premium - I
# 25999       16745.3     Premium - J
# 27130       19061.9        Fair - H
# 27630       20384.1        Fair - J
# 27415       19819.8        Fair - J
#
# [53938 rows x 10 columns]

# %%
df_carat_d = df.sort_values(by='carat',ascending= False)

# %%
df_carat_d
# Out:
#        carat cutDiamond ColorInitial clarity  price      x      y     z  \
# 27415   5.01       Fair            J      I1  18018  10.74  10.54  6.98
# 27630   4.50       Fair            J      I1  18531  10.23  10.16  6.72
# 27130   4.13       Fair            H      I1  17329  10.00   9.85  6.43
# 25999   4.01    Premium            J      I1  15223  10.02   9.94  6.24
# 25998   4.01    Premium            I      I1  15223  10.14  10.10  6.17
# ...      ...        ...          ...     ...    ...    ...    ...   ...
# 31598   0.20  Very Good            E     VS2    367   3.74   3.71  2.36
# 31599   0.20      Ideal            E     VS2    367   3.76   3.73  2.33
# 31600   0.20    Premium            D     VS2    367   3.73   3.68  2.31
# 31601   0.20    Premium            D     VS2    367   3.77   3.72  2.31
# 31596   0.20    Premium            F     VS2    367   3.73   3.71  2.33
#
#        priceUpdated Quality - color
# 27415       19819.8        Fair - J
# 27630       20384.1        Fair - J
# 27130       19061.9        Fair - H
# 25999       16745.3     Premium - J
# 25998       16745.3     Premium - I
# ...             ...             ...
# 31598         403.7   Very Good - E
# 31599         403.7       Ideal - E
# 31600         403.7     Premium - D
# 31601         403.7     Premium - D
# 31596         403.7     Premium - F
#
# [53938 rows x 10 columns]

# %% [markdown]
# ### 15. Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

# %%
df_c = df[df['carat']>=0.3]
df_c
# Out:
#        carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 4       0.31       Good            J     SI2    335  4.34  4.35  2.75
# 10      0.30       Good            J     SI1    339  4.25  4.28  2.73
# 13      0.31      Ideal            J     SI2    344  4.35  4.37  2.71
# 15      0.32    Premium            E      I1    345  4.38  4.42  2.68
# 16      0.30      Ideal            I     SI2    348  4.31  4.34  2.68
# ...      ...        ...          ...     ...    ...   ...   ...   ...
# 53933   0.70  Very Good            E     VS2   2757  5.69  5.72  3.49
# 53934   0.72    Premium            D     SI1   2757  5.69  5.73  3.58
# 53935   0.72      Ideal            D     SI1   2757  5.75  5.76  3.50
# 53936   0.72       Good            D     SI1   2757  5.69  5.75  3.61
# 53939   0.75      Ideal            D     SI2   2757  5.83  5.87  3.64
#
#        priceUpdated Quality - color
# 4             368.5        Good - J
# 10            372.9        Good - J
# 13            378.4       Ideal - J
# 15            379.5     Premium - E
# 16            382.8       Ideal - I
# ...             ...             ...
# 53933        3032.7   Very Good - E
# 53934        3032.7     Premium - D
# 53935        3032.7       Ideal - D
# 53936        3032.7        Good - D
# 53939        3032.7       Ideal - D
#
# [52339 rows x 10 columns]

# %% [markdown]
# ### 16. Write a Pandas program to convert a python list to pandas series.

# %%
lst = ['python','data analytics','AI',100.0,'Machine Learning']
s1 = pd.Series(lst)
s1
# Out:
# 0              python
# 1      data analytics
# 2                  AI
# 3               100.0
# 4    Machine Learning
# dtype: object

# %% [markdown]
# ### 17. Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

# %%
df_new = df[(df['x']>5) & (df['y']>5) & (df['z']>5)]
df_new.head(7)
# Out:
#        carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 11778   1.83       Fair            J      I1   5083  7.34  7.28  5.12
# 13002   2.14       Fair            J      I1   5405  7.74  7.70  5.36
# 13118   2.15       Fair            J      I1   5430  8.01  7.95  5.23
# 13562   1.96       Fair            F      I1   5554  7.59  7.56  5.04
# 13757   2.22       Fair            J      I1   5607  8.04  8.02  5.36
# 13929   2.00       Fair            I      I1   5667  7.78  7.74  5.10
# 13991   2.01       Fair            I      I1   5696  7.71  7.64  5.17
#
#        priceUpdated Quality - color
# 11778        5591.3        Fair - J
# 13002        5945.5        Fair - J
# 13118        5973.0        Fair - J
# 13562        6109.4        Fair - F
# 13757        6167.7        Fair - J
# 13929        6233.7        Fair - I
# 13991        6265.6        Fair - I

# %%
df_new.describe().T
# Out:
#                count          mean          std      min       25%       50%  \
# carat         1457.0      2.181551     0.270744     0.50      2.02      2.10
# price         1457.0  14751.994509  2948.426286  1970.00  13006.00  15223.00
# x             1457.0      8.263089     0.360554     5.01      8.06      8.21
# y             1457.0      8.291874     1.503095     5.04      8.04      8.19
# z             1457.0      5.179897     0.725940     5.01      5.05      5.10
# priceUpdated  1457.0  16227.193960  3243.268914  2167.00  14306.60  16745.30
#
#                    75%       max
# carat             2.25      5.01
# price         17051.00  18823.00
# x                 8.42     10.74
# y                 8.40     58.90
# z                 5.21     31.80
# priceUpdated  18756.10  20705.30

# %% [markdown]
# ### 18. Write a Pandas program to find the diamonds that are either Premium or Ideal.

# %%
df1 = df[(df['cutDiamond']=="Premium") | (df['cutDiamond']=="Ideal")]
df1.head(7)
# Out:
#     carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 0    0.23      Ideal            E     SI2    326  3.95  3.98  2.43
# 1    0.21    Premium            E     SI1    326  3.89  3.84  2.31
# 3    0.29    Premium            I     VS2    334  4.20  4.23  2.63
# 11   0.23      Ideal            J     VS1    340  3.93  3.90  2.46
# 12   0.22    Premium            F     SI1    342  3.88  3.84  2.33
# 13   0.31      Ideal            J     SI2    344  4.35  4.37  2.71
# 14   0.20    Premium            E     SI2    345  3.79  3.75  2.27
#
#     priceUpdated Quality - color
# 0          358.6       Ideal - E
# 1          358.6     Premium - E
# 3          367.4     Premium - I
# 11         374.0       Ideal - J
# 12         376.2     Premium - F
# 13         378.4       Ideal - J
# 14         379.5     Premium - E

# %% [markdown]
# ### 19. Write a Pandas program to find the diamonds that are with a Fair or Good or Premium.

# %%
df2 = df[(df['cutDiamond']=="Premium") | (df['cutDiamond']=="Good") | (df['cutDiamond']=="Fair") ]
df2
# Out:
#        carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 1       0.21    Premium            E     SI1    326  3.89  3.84  2.31
# 2       0.23       Good            E     VS1    327  4.05  4.07  2.31
# 3       0.29    Premium            I     VS2    334  4.20  4.23  2.63
# 4       0.31       Good            J     SI2    335  4.34  4.35  2.75
# 8       0.22       Fair            E     VS2    337  3.87  3.78  2.49
# ...      ...        ...          ...     ...    ...   ...   ...   ...
# 53928   0.79    Premium            E     SI2   2756  6.03  5.96  3.68
# 53930   0.71    Premium            E     SI1   2756  5.79  5.74  3.49
# 53931   0.71    Premium            F     SI1   2756  5.74  5.73  3.43
# 53934   0.72    Premium            D     SI1   2757  5.69  5.73  3.58
# 53936   0.72       Good            D     SI1   2757  5.69  5.75  3.61
#
#        priceUpdated Quality - color
# 1             358.6     Premium - E
# 2             359.7        Good - E
# 3             367.4     Premium - I
# 4             368.5        Good - J
# 8             370.7        Fair - E
# ...             ...             ...
# 53928        3031.6     Premium - E
# 53930        3031.6     Premium - E
# 53931        3031.6     Premium - F
# 53934        3032.7     Premium - D
# 53936        3032.7        Good - D
#
# [20306 rows x 10 columns]

# %% [markdown]
# ### 20. Write a Pandas program to display all column labels of diamonds DataFrame.

# %%
column_labels  = df.columns
column_labels
# Out:
# Index(['carat', 'cutDiamond', 'ColorInitial', 'clarity', 'price', 'x', 'y',
#        'z', 'priceUpdated', 'Quality - color'],
#       dtype='object')

# %% [markdown]
# ### 21. Write a Pandas program to read only a subset of 3 rows from diamonds DataFrame.

# %%
# df.head(3)

df.iloc[210:213]
# Out:
#      carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 210   0.70  Very Good            F     VS2   2780  5.61  5.65  3.58
# 211   0.77    Premium            G     VS2   2780  5.90  5.93  3.62
# 212   0.71      Ideal            F     VS2   2780  5.68  5.72  3.54
#
#      priceUpdated Quality - color
# 210        3058.0   Very Good - F
# 211        3058.0     Premium - G
# 212        3058.0       Ideal - F

# %% [markdown]
# ### 22. Write a Pandas program to iterate through diamonds DataFrame.

# %%
df_it = df.iloc[2:50]
df_res = df_it[df_it['x']>4]
df_res
# Out:
#     carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 2    0.23       Good            E     VS1    327  4.05  4.07  2.31
# 3    0.29    Premium            I     VS2    334  4.20  4.23  2.63
# 4    0.31       Good            J     SI2    335  4.34  4.35  2.75
# 7    0.26  Very Good            H     SI1    337  4.07  4.11  2.53
# 10   0.30       Good            J     SI1    339  4.25  4.28  2.73
# 13   0.31      Ideal            J     SI2    344  4.35  4.37  2.71
# 15   0.32    Premium            E      I1    345  4.38  4.42  2.68
# 16   0.30      Ideal            I     SI2    348  4.31  4.34  2.68
# 17   0.30       Good            J     SI1    351  4.23  4.29  2.70
# 18   0.30       Good            J     SI1    351  4.23  4.26  2.71
# 19   0.30  Very Good            J     SI1    351  4.21  4.27  2.66
# 20   0.30       Good            I     SI2    351  4.26  4.30  2.71
# 23   0.31  Very Good            J     SI1    353  4.39  4.43  2.62
# 24   0.31  Very Good            J     SI1    353  4.44  4.47  2.59
# 27   0.30  Very Good            J     VS2    357  4.28  4.30  2.67
# 31   0.23  Very Good            F     VS1    402  4.04  4.06  2.42
# 33   0.23  Very Good            E     VS1    402  4.01  4.06  2.40
# 35   0.23       Good            F     VS1    402  4.06  4.08  2.37
# 37   0.31       Good            H     SI1    402  4.29  4.31  2.75
# 38   0.26  Very Good            D     VS2    403  4.13  4.16  2.52
# 39   0.33      Ideal            I     SI2    403  4.49  4.51  2.78
# 40   0.33      Ideal            I     SI2    403  4.49  4.50  2.75
# 41   0.33      Ideal            J     SI1    403  4.49  4.55  2.76
# 43   0.26       Good            D     VS1    403  4.19  4.24  2.46
# 44   0.32       Good            H     SI2    403  4.34  4.37  2.75
# 45   0.29    Premium            F     SI1    403  4.24  4.26  2.65
# 46   0.32  Very Good            H     SI2    403  4.35  4.42  2.71
# 47   0.32       Good            H     SI2    403  4.36  4.38  2.79
# 49   0.29  Very Good            H     SI2    404  4.33  4.37  2.64
#
#     priceUpdated Quality - color
# 2          359.7        Good - E
# 3          367.4     Premium - I
# 4          368.5        Good - J
# 7          370.7   Very Good - H
# 10         372.9        Good - J
# 13         378.4       Ideal - J
# 15         379.5     Premium - E
# 16         382.8       Ideal - I
# 17         386.1        Good - J
# 18         386.1        Good - J
# 19         386.1   Very Good - J
# 20         386.1        Good - I
# 23         388.3   Very Good - J
# 24         388.3   Very Good - J
# 27         392.7   Very Good - J
# 31         442.2   Very Good - F
# 33         442.2   Very Good - E
# 35         442.2        Good - F
# 37         442.2        Good - H
# 38         443.3   Very Good - D
# 39         443.3       Ideal - I
# 40         443.3       Ideal - I
# 41         443.3       Ideal - J
# 43         443.3        Good - D
# 44         443.3        Good - H
# 45         443.3     Premium - F
# 46         443.3   Very Good - H
# 47         443.3        Good - H
# 49         444.4   Very Good - H

# %% [markdown]
# ### 23. Write a Pandas program to drop all non-numeric columns from diamonds DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53938 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   carat            53938 non-null  float64
#  1   cutDiamond       53938 non-null  object
#  2   ColorInitial     53938 non-null  object
#  3   clarity          53938 non-null  object
#  4   price            53938 non-null  int64
#  5   x                53938 non-null  float64
#  6   y                53938 non-null  float64
#  7   z                53938 non-null  float64
#  8   priceUpdated     53938 non-null  float64
#  9   Quality - color  53938 non-null  object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
# Drop columns with dtype 'object' in place

df_drop = df.drop(columns=df.select_dtypes(include=['object']).columns)

# %%
df_drop
# Out:
#        carat  price     x     y     z  priceUpdated
# 0       0.23    326  3.95  3.98  2.43         358.6
# 1       0.21    326  3.89  3.84  2.31         358.6
# 2       0.23    327  4.05  4.07  2.31         359.7
# 3       0.29    334  4.20  4.23  2.63         367.4
# 4       0.31    335  4.34  4.35  2.75         368.5
# ...      ...    ...   ...   ...   ...           ...
# 53933   0.70   2757  5.69  5.72  3.49        3032.7
# 53934   0.72   2757  5.69  5.73  3.58        3032.7
# 53935   0.72   2757  5.75  5.76  3.50        3032.7
# 53936   0.72   2757  5.69  5.75  3.61        3032.7
# 53939   0.75   2757  5.83  5.87  3.64        3032.7
#
# [53938 rows x 6 columns]

# %% [markdown]
# ### 24. Write a Pandas program to include only numeric columns in the diamondsDataFrame.

# %%
df_select = df.select_dtypes(exclude=['object'])
df_select
# Out:
#        carat  price     x     y     z  priceUpdated
# 0       0.23    326  3.95  3.98  2.43         358.6
# 1       0.21    326  3.89  3.84  2.31         358.6
# 2       0.23    327  4.05  4.07  2.31         359.7
# 3       0.29    334  4.20  4.23  2.63         367.4
# 4       0.31    335  4.34  4.35  2.75         368.5
# ...      ...    ...   ...   ...   ...           ...
# 53933   0.70   2757  5.69  5.72  3.49        3032.7
# 53934   0.72   2757  5.69  5.73  3.58        3032.7
# 53935   0.72   2757  5.75  5.76  3.50        3032.7
# 53936   0.72   2757  5.69  5.75  3.61        3032.7
# 53939   0.75   2757  5.83  5.87  3.64        3032.7
#
# [53938 rows x 6 columns]

# %% [markdown]
# ### 25. Write a Pandas program to pass a list of data types to only describe certain types of diamonds DataFrame.

# %%
lst = ['float64', 'int64']

df_certainDtype = df.select_dtypes(include=lst)
df_certainDtype.describe()
# Out:
#              carat         price             x             y             z  \
# count  53938.00000  53938.000000  53938.000000  53938.000000  53938.000000
# mean       0.79794   3932.843320      5.731151      5.734520      3.538730
# std        0.47402   3989.507277      1.121780      1.142155      0.705711
# min        0.20000    326.000000      0.000000      0.000000      0.000000
# 25%        0.40000    950.000000      4.710000      4.720000      2.910000
# 50%        0.70000   2401.000000      5.700000      5.710000      3.530000
# 75%        1.04000   5324.750000      6.540000      6.540000      4.040000
# max        5.01000  18823.000000     10.740000     58.900000     31.800000
#
#        priceUpdated
# count  53938.000000
# mean    4326.127652
# std     4388.458005
# min      358.600000
# 25%     1045.000000
# 50%     2641.100000
# 75%     5857.225000
# max    20705.300000

# %% [markdown]
# ### 26. Write a Pandas program to calculate the mean of each numeric column of diamonds DataFrame.

# %%
df_certainDtype.mean()
# Out:
# carat              0.797940
# price           3932.843320
# x                  5.731151
# y                  5.734520
# z                  3.538730
# priceUpdated    4326.127652
# dtype: float64

# %% [markdown]
# ### 27. Write a Pandas program to calculate the mean of each row of diamonds DataFrame.

# %%
df_certainDtype.mean(axis=1)
# Out:
# 0        115.865000
# 1        115.808333
# 2        116.226667
# 3        118.791667
# 4        119.208333
#             ...
# 53933    967.550000
# 53934    967.570000
# 53935    967.571667
# 53936    967.578333
# 53939    967.631667
# Length: 53938, dtype: float64

# %% [markdown]
# ### 28. Write a Pandas program to calculate the mean of price for each cut of diamonds DataFrame.

# %%
df_cut = df.groupby('cutDiamond')
price_bycut = df_cut['price']
price_bycut.mean()
# Out:
# cutDiamond
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.390210
# Very Good    3981.861270
# Name: price, dtype: float64

# %% [markdown]
# ### 29. Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame.

# %%
print(f"Calculate Count: {price_bycut.count()}\n")
print(f"Calculate Minimum: {price_bycut.min()}\n")
print(f"Calculate Maximum: {price_bycut.max()}\n")
# Out:
# Calculate Count: cutDiamond
# Fair          1610
# Good          4906
# Ideal        21551
# Premium      13790
# Very Good    12081
# Name: price, dtype: int64
#
# Calculate Minimum: cutDiamond
# Fair         337
# Good         327
# Ideal        326
# Premium      326
# Very Good    336
# Name: price, dtype: int64
#
# Calculate Maximum: cutDiamond
# Fair         18574
# Good         18788
# Ideal        18806
# Premium      18823
# Very Good    18818
# Name: price, dtype: int64

# %% [markdown]
# ### 30. Write a Pandas program to create a side-by-side bar plot of the diamonds DataFrame.

# %%
# Calculate the average price for each combination of cut and color
average_price = df.groupby(['cutDiamond', 'ColorInitial'])['price'].mean().unstack()

# Create a side-by-side bar plot
average_price.plot(kind='bar', figsize=(12, 6))
# Out:
# <Axes: xlabel='cutDiamond'>

# %% [markdown]
# ### 31. Write a Pandas program to count how many times each value in cut series of  diamonds DataFrame occurs

# %%
series = df['cutDiamond']
s1 = series.value_counts()
s1
# Out:
# cutDiamond
# Ideal        21551
# Premium      13790
# Very Good    12081
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %% [markdown]
# ### 32. Write a Pandas program to display percentages of each value of cut series occurs in diamonds DataFrame.

# %%
percentage = (s1 / s1.sum()) * 100
percentage
# Out:
# cutDiamond
# Ideal        39.955134
# Premium      25.566391
# Very Good    22.397938
# Good          9.095628
# Fair          2.984909
# Name: count, dtype: float64

# %% [markdown]
# ### 33. Write a Pandas program to display the unique values in cut series of diamonds DataFrame.

# %%
unique_values = series.unique()
unique_values
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %% [markdown]
# ### 34. Write a Pandas program to count the number of unique values in cut series of diamonds DataFrame.

# %%
unique_valueCount = df['cutDiamond'].nunique()
unique_valueCount
# Out:
# 5

# %% [markdown]
# ### 35. Write a Pandas program to compute a cross-tabulation of two Series in diamonds DataFrame.

# %%
# Compute the cross-tabulation of 'cut' and 'color'
crosstab_result = pd.crosstab(df['cutDiamond'], df['ColorInitial'])

crosstab_result
# Out:
# ColorInitial     D     E     F     G     H     I    J
# cutDiamond
# Fair           163   224   312   314   303   175  119
# Good           662   933   909   871   702   522  307
# Ideal         2834  3903  3826  4884  3115  2093  896
# Premium       1603  2337  2331  2924  2359  1428  808
# Very Good     1512  2400  2164  2299  1824  1204  678

# %% [markdown]
# ### 36. Write a Pandas program to calculate various summary statistics of cut series of diamonds DataFrame.

# %%
cut_series = df["cutDiamond"]
cut_series.describe()
# Out:
# count     53938
# unique        5
# top       Ideal
# freq      21551
# Name: cutDiamond, dtype: object

# %% [markdown]
# ### 37. Write a Pandas program to create a histogram of the 'carat' Series (distribution of a numerical variable) of diamonds DataFrame.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_filtered = df.sort_values(by='carat')

sns.displot(data=df_filtered,x='carat',kde=True,height=8, aspect=2, bins=30)
plt.show()

# %% [markdown]
# ### 38. Write a Pandas program to create a bar plot of the 'value_counts' for the 'cut' series of diamonds DataFrame.

# %%
plt.figure(figsize =(8,5),dpi = 80) #dpi = Dots per Inch of space
sns.countplot(x="cutDiamond",data= df)
plt.show()

# %% [markdown]
# ### 39. Write a Pandas program to create a DataFrame of booleans (True if missing, False if not missing) from diamonds DataFrame.

# %%
df_bool = df.isnull()
df_bool
# Out:
#        carat  cutDiamond  ColorInitial  clarity  price      x      y      z  \
# 0      False       False         False    False  False  False  False  False
# 1      False       False         False    False  False  False  False  False
# 2      False       False         False    False  False  False  False  False
# 3      False       False         False    False  False  False  False  False
# 4      False       False         False    False  False  False  False  False
# ...      ...         ...           ...      ...    ...    ...    ...    ...
# 53933  False       False         False    False  False  False  False  False
# 53934  False       False         False    False  False  False  False  False
# 53935  False       False         False    False  False  False  False  False
# 53936  False       False         False    False  False  False  False  False
# 53939  False       False         False    False  False  False  False  False
#
#        priceUpdated  Quality - color
# 0             False            False
# 1             False            False
# 2             False            False
# 3             False            False
# 4             False            False
# ...             ...              ...
# 53933         False            False
# 53934         False            False
# 53935         False            False
# 53936         False            False
# 53939         False            False
#
# [53938 rows x 10 columns]

# %% [markdown]
# ### 40. Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame.

# %%
df.isnull().sum()
# Out:
# carat              0
# cutDiamond         0
# ColorInitial       0
# clarity            0
# price              0
# x                  0
# y                  0
# z                  0
# priceUpdated       0
# Quality - color    0
# dtype: int64

# %% [markdown]
# ### 41. Write a Pandas program to check the number of rows and columns and drop those row if 'any' values are missing in a row of diamonds DataFrame.

# %%
A = df.dropna()
A
# Out:
#        carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 0       0.23      Ideal            E     SI2    326  3.95  3.98  2.43
# 1       0.21    Premium            E     SI1    326  3.89  3.84  2.31
# 2       0.23       Good            E     VS1    327  4.05  4.07  2.31
# 3       0.29    Premium            I     VS2    334  4.20  4.23  2.63
# 4       0.31       Good            J     SI2    335  4.34  4.35  2.75
# ...      ...        ...          ...     ...    ...   ...   ...   ...
# 53933   0.70  Very Good            E     VS2   2757  5.69  5.72  3.49
# 53934   0.72    Premium            D     SI1   2757  5.69  5.73  3.58
# 53935   0.72      Ideal            D     SI1   2757  5.75  5.76  3.50
# 53936   0.72       Good            D     SI1   2757  5.69  5.75  3.61
# 53939   0.75      Ideal            D     SI2   2757  5.83  5.87  3.64
#
#        priceUpdated Quality - color
# 0             358.6       Ideal - E
# 1             358.6     Premium - E
# 2             359.7        Good - E
# 3             367.4     Premium - I
# 4             368.5        Good - J
# ...             ...             ...
# 53933        3032.7   Very Good - E
# 53934        3032.7     Premium - D
# 53935        3032.7       Ideal - D
# 53936        3032.7        Good - D
# 53939        3032.7       Ideal - D
#
# [53938 rows x 10 columns]

# %% [markdown]
# ### 42. Write a Pandas program to drop a row if any or all values in a row are missing of diamonds DataFrame on two specific columns.

# %%
columns_to_check = ['carat','x']
# Drop rows where any values in the specified columns are missing
B = df.dropna(subset=columns_to_check, how='any')
B
# Drop rows where all values in the specified columns are missing
# diamonds_all_dropped = df.dropna(subset=columns_to_check, how='all')
# Out:
#        carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 0       0.23      Ideal            E     SI2    326  3.95  3.98  2.43
# 1       0.21    Premium            E     SI1    326  3.89  3.84  2.31
# 2       0.23       Good            E     VS1    327  4.05  4.07  2.31
# 3       0.29    Premium            I     VS2    334  4.20  4.23  2.63
# 4       0.31       Good            J     SI2    335  4.34  4.35  2.75
# ...      ...        ...          ...     ...    ...   ...   ...   ...
# 53933   0.70  Very Good            E     VS2   2757  5.69  5.72  3.49
# 53934   0.72    Premium            D     SI1   2757  5.69  5.73  3.58
# 53935   0.72      Ideal            D     SI1   2757  5.75  5.76  3.50
# 53936   0.72       Good            D     SI1   2757  5.69  5.75  3.61
# 53939   0.75      Ideal            D     SI2   2757  5.83  5.87  3.64
#
#        priceUpdated Quality - color
# 0             358.6       Ideal - E
# 1             358.6     Premium - E
# 2             359.7        Good - E
# 3             367.4     Premium - I
# 4             368.5        Good - J
# ...             ...             ...
# 53933        3032.7   Very Good - E
# 53934        3032.7     Premium - D
# 53935        3032.7       Ideal - D
# 53936        3032.7        Good - D
# 53939        3032.7       Ideal - D
#
# [53938 rows x 10 columns]

# %% [markdown]
# ### 43. Write a Pandas program to set an existing column as the index of diamonds DataFrame.

# %%
dfset= df.set_index('Quality - color')
dfset
# Out:
#                  carat cutDiamond ColorInitial clarity  price     x     y  \
# Quality - color
# Ideal - E         0.23      Ideal            E     SI2    326  3.95  3.98
# Premium - E       0.21    Premium            E     SI1    326  3.89  3.84
# Good - E          0.23       Good            E     VS1    327  4.05  4.07
# Premium - I       0.29    Premium            I     VS2    334  4.20  4.23
# Good - J          0.31       Good            J     SI2    335  4.34  4.35
# ...                ...        ...          ...     ...    ...   ...   ...
# Very Good - E     0.70  Very Good            E     VS2   2757  5.69  5.72
# Premium - D       0.72    Premium            D     SI1   2757  5.69  5.73
# Ideal - D         0.72      Ideal            D     SI1   2757  5.75  5.76
# Good - D          0.72       Good            D     SI1   2757  5.69  5.75
# Ideal - D         0.75      Ideal            D     SI2   2757  5.83  5.87
#
#                     z  priceUpdated
# Quality - color
# Ideal - E        2.43         358.6
# Premium - E      2.31         358.6
# Good - E         2.31         359.7
# Premium - I      2.63         367.4
# Good - J         2.75         368.5
# ...               ...           ...
# Very Good - E    3.49        3032.7
# Premium - D      3.58        3032.7
# Ideal - D        3.50        3032.7
# Good - D         3.61        3032.7
# Ideal - D        3.64        3032.7
#
# [53938 rows x 9 columns]

# %% [markdown]
# ### 44. Write a Pandas program to set an existing column as the index of diamonds DataFrame and restore the index name, and move the index back to a column.

# %%
df_set = df.set_index('x')
df_set
# Out:
#       carat cutDiamond ColorInitial clarity  price     y     z  priceUpdated  \
# x
# 3.95   0.23      Ideal            E     SI2    326  3.98  2.43         358.6
# 3.89   0.21    Premium            E     SI1    326  3.84  2.31         358.6
# 4.05   0.23       Good            E     VS1    327  4.07  2.31         359.7
# 4.20   0.29    Premium            I     VS2    334  4.23  2.63         367.4
# 4.34   0.31       Good            J     SI2    335  4.35  2.75         368.5
# ...     ...        ...          ...     ...    ...   ...   ...           ...
# 5.69   0.70  Very Good            E     VS2   2757  5.72  3.49        3032.7
# 5.69   0.72    Premium            D     SI1   2757  5.73  3.58        3032.7
# 5.75   0.72      Ideal            D     SI1   2757  5.76  3.50        3032.7
# 5.69   0.72       Good            D     SI1   2757  5.75  3.61        3032.7
# 5.83   0.75      Ideal            D     SI2   2757  5.87  3.64        3032.7
#
#      Quality - color
# x
# 3.95       Ideal - E
# 3.89     Premium - E
# 4.05        Good - E
# 4.20     Premium - I
# 4.34        Good - J
# ...              ...
# 5.69   Very Good - E
# 5.69     Premium - D
# 5.75       Ideal - D
# 5.69        Good - D
# 5.83       Ideal - D
#
# [53938 rows x 9 columns]

# %%
df_reset = df.reset_index()
df_reset
# Out:
#        index  carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 0          0   0.23      Ideal            E     SI2    326  3.95  3.98  2.43
# 1          1   0.21    Premium            E     SI1    326  3.89  3.84  2.31
# 2          2   0.23       Good            E     VS1    327  4.05  4.07  2.31
# 3          3   0.29    Premium            I     VS2    334  4.20  4.23  2.63
# 4          4   0.31       Good            J     SI2    335  4.34  4.35  2.75
# ...      ...    ...        ...          ...     ...    ...   ...   ...   ...
# 53933  53933   0.70  Very Good            E     VS2   2757  5.69  5.72  3.49
# 53934  53934   0.72    Premium            D     SI1   2757  5.69  5.73  3.58
# 53935  53935   0.72      Ideal            D     SI1   2757  5.75  5.76  3.50
# 53936  53936   0.72       Good            D     SI1   2757  5.69  5.75  3.61
# 53937  53939   0.75      Ideal            D     SI2   2757  5.83  5.87  3.64
#
#        priceUpdated Quality - color
# 0             358.6       Ideal - E
# 1             358.6     Premium - E
# 2             359.7        Good - E
# 3             367.4     Premium - I
# 4             368.5        Good - J
# ...             ...             ...
# 53933        3032.7   Very Good - E
# 53934        3032.7     Premium - D
# 53935        3032.7       Ideal - D
# 53936        3032.7        Good - D
# 53937        3032.7       Ideal - D
#
# [53938 rows x 11 columns]

# %% [markdown]
# ### 45. Write a Pandas program to access a specified Series index and the Series values of diamonds DataFrame

# %%
df_set.index
# Out:
# Index([3.95, 3.89, 4.05,  4.2, 4.34, 3.94, 3.95, 4.07, 3.87,  4.0,
#        ...
#        6.03, 5.76, 5.79, 5.74, 5.71, 5.69, 5.69, 5.75, 5.69, 5.83],
#       dtype='float64', name='x', length=53938)

# %% [markdown]
# ### 46. Write a Pandas program to sort a Series by its values and index of diamonds DataFrame.

# %%
df_set.sort_index()
# Out:
#        carat cutDiamond ColorInitial clarity  price      y     z  \
# x
# 0.00    1.07      Ideal            F     SI2   4954   6.62  0.00
# 0.00    1.00  Very Good            H     VS2   5139   0.00  0.00
# 0.00    1.20    Premium            D    VVS1  15686   0.00  0.00
# 0.00    1.56      Ideal            G     VS2  12800   0.00  0.00
# 0.00    0.71       Good            F     SI2   2130   0.00  0.00
# ...      ...        ...          ...     ...    ...    ...   ...
# 10.01   4.00  Very Good            I      I1  15984   9.94  6.31
# 10.02   4.01    Premium            J      I1  15223   9.94  6.24
# 10.14   4.01    Premium            I      I1  15223  10.10  6.17
# 10.23   4.50       Fair            J      I1  18531  10.16  6.72
# 10.74   5.01       Fair            J      I1  18018  10.54  6.98
#
#        priceUpdated Quality - color
# x
# 0.00         5449.4       Ideal - F
# 0.00         5652.9   Very Good - H
# 0.00        17254.6     Premium - D
# 0.00        14080.0       Ideal - G
# 0.00         2343.0        Good - F
# ...             ...             ...
# 10.01       17582.4   Very Good - I
# 10.02       16745.3     Premium - J
# 10.14       16745.3     Premium - I
# 10.23       20384.1        Fair - J
# 10.74       19819.8        Fair - J
#
# [53938 rows x 9 columns]

# %% [markdown]
# ### 47. Write a Pandas program to calculate the multiply of length, width and depth for each cut of diamonds DataFrame.

# %%
df['volume'] = df['x'] * df['y'] * df['z']

mean_volume_by_cut = df.groupby('cutDiamond')['volume'].mean()

# Display the result
print("Mean volume for each cut of diamonds:")
print(mean_volume_by_cut)
# Out:
# Mean volume for each cut of diamonds:
# cutDiamond
# Fair         164.950549
# Good         136.257267
# Ideal        115.394912
# Premium      145.052439
# Very Good    131.001092
# Name: volume, dtype: float64

# %% [markdown]
# ### 48. Write a Pandas program to concatenate the diamonds DataFrame with the 'color' Series.

# %%
df1 = pd.DataFrame(data={'color': df['ColorInitial']})

# Concatenate df1 to the original df
df = pd.concat([df, df1], axis=1)
df
# Out:
#        carat cutDiamond ColorInitial clarity  price     x     y     z  \
# 0       0.23      Ideal            E     SI2    326  3.95  3.98  2.43
# 1       0.21    Premium            E     SI1    326  3.89  3.84  2.31
# 2       0.23       Good            E     VS1    327  4.05  4.07  2.31
# 3       0.29    Premium            I     VS2    334  4.20  4.23  2.63
# 4       0.31       Good            J     SI2    335  4.34  4.35  2.75
# ...      ...        ...          ...     ...    ...   ...   ...   ...
# 53933   0.70  Very Good            E     VS2   2757  5.69  5.72  3.49
# 53934   0.72    Premium            D     SI1   2757  5.69  5.73  3.58
# 53935   0.72      Ideal            D     SI1   2757  5.75  5.76  3.50
# 53936   0.72       Good            D     SI1   2757  5.69  5.75  3.61
# 53939   0.75      Ideal            D     SI2   2757  5.83  5.87  3.64
#
#        priceUpdated Quality - color      volume color
# 0             358.6       Ideal - E   38.202030     E
# 1             358.6     Premium - E   34.505856     E
# 2             359.7        Good - E   38.076885     E
# 3             367.4     Premium - I   46.724580     I
# 4             368.5        Good - J   51.917250     J
# ...             ...             ...         ...   ...
# 53933        3032.7   Very Good - E  113.588332     E
# 53934        3032.7     Premium - D  116.721246     D
# 53935        3032.7       Ideal - D  115.920000     D
# 53936        3032.7        Good - D  118.110175     D
# 53939        3032.7       Ideal - D  124.568444     D
#
# [53938 rows x 12 columns]

# %%
df.drop(columns='ColorInitial',inplace = True)

# %%
df
# Out:
#        carat cutDiamond clarity  price     x     y     z  priceUpdated  \
# 0       0.23      Ideal     SI2    326  3.95  3.98  2.43         358.6
# 1       0.21    Premium     SI1    326  3.89  3.84  2.31         358.6
# 2       0.23       Good     VS1    327  4.05  4.07  2.31         359.7
# 3       0.29    Premium     VS2    334  4.20  4.23  2.63         367.4
# 4       0.31       Good     SI2    335  4.34  4.35  2.75         368.5
# ...      ...        ...     ...    ...   ...   ...   ...           ...
# 53933   0.70  Very Good     VS2   2757  5.69  5.72  3.49        3032.7
# 53934   0.72    Premium     SI1   2757  5.69  5.73  3.58        3032.7
# 53935   0.72      Ideal     SI1   2757  5.75  5.76  3.50        3032.7
# 53936   0.72       Good     SI1   2757  5.69  5.75  3.61        3032.7
# 53939   0.75      Ideal     SI2   2757  5.83  5.87  3.64        3032.7
#
#       Quality - color      volume color
# 0           Ideal - E   38.202030     E
# 1         Premium - E   34.505856     E
# 2            Good - E   38.076885     E
# 3         Premium - I   46.724580     I
# 4            Good - J   51.917250     J
# ...               ...         ...   ...
# 53933   Very Good - E  113.588332     E
# 53934     Premium - D  116.721246     D
# 53935       Ideal - D  115.920000     D
# 53936        Good - D  118.110175     D
# 53939       Ideal - D  124.568444     D
#
# [53938 rows x 11 columns]

# %% [markdown]
# ### 49. Write a Pandas program to read specified rows and all columns of diamonds DataFrame.

# %%
df.iloc[5:12]
# Out:
#     carat cutDiamond clarity  price     x     y     z  priceUpdated  \
# 5    0.24  Very Good    VVS2    336  3.94  3.96  2.48         369.6
# 6    0.24  Very Good    VVS1    336  3.95  3.98  2.47         369.6
# 7    0.26  Very Good     SI1    337  4.07  4.11  2.53         370.7
# 8    0.22       Fair     VS2    337  3.87  3.78  2.49         370.7
# 9    0.23  Very Good     VS1    338  4.00  4.05  2.39         371.8
# 10   0.30       Good     SI1    339  4.25  4.28  2.73         372.9
# 11   0.23      Ideal     VS1    340  3.93  3.90  2.46         374.0
#
#    Quality - color     volume color
# 5    Very Good - J  38.693952     J
# 6    Very Good - I  38.830870     I
# 7    Very Good - H  42.321081     H
# 8         Fair - E  36.425214     E
# 9    Very Good - H  38.718000     H
# 10        Good - J  49.658700     J
# 11       Ideal - J  37.704420     J

# %% [markdown]
# ### 50. Write a Pandas program to read rows 0, 5, 7 and all columns of diamonds DataFrame.

# %%
df.iloc[[0,5,7]]
# Out:
#    carat cutDiamond clarity  price     x     y     z  priceUpdated  \
# 0   0.23      Ideal     SI2    326  3.95  3.98  2.43         358.6
# 5   0.24  Very Good    VVS2    336  3.94  3.96  2.48         369.6
# 7   0.26  Very Good     SI1    337  4.07  4.11  2.53         370.7
#
#   Quality - color     volume color
# 0       Ideal - E  38.202030     E
# 5   Very Good - J  38.693952     J
# 7   Very Good - H  42.321081     H

# %% [markdown]
# ### 51. Write a Pandas program to read rows 2 through 5 and all columns of diamonds DataFrame.

# %%
df.iloc[2:6]
# Out:
#    carat cutDiamond clarity  price     x     y     z  priceUpdated  \
# 2   0.23       Good     VS1    327  4.05  4.07  2.31         359.7
# 3   0.29    Premium     VS2    334  4.20  4.23  2.63         367.4
# 4   0.31       Good     SI2    335  4.34  4.35  2.75         368.5
# 5   0.24  Very Good    VVS2    336  3.94  3.96  2.48         369.6
#
#   Quality - color     volume color
# 2        Good - E  38.076885     E
# 3     Premium - I  46.724580     I
# 4        Good - J  51.917250     J
# 5   Very Good - J  38.693952     J

# %% [markdown]
# ### 52. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color' and 'price' of diamonds DataFrame.

# %%
df[['color','price']].iloc[0:3]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %% [markdown]
# ### 53. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'x' through 'z' (inclusive) of diamonds DataFrame.

# %%
df.loc[0:2,'x':'z']
# Out:
#       x     y     z
# 0  3.95  3.98  2.43
# 1  3.89  3.84  2.31
# 2  4.05  4.07  2.31

# %% [markdown]
# ### 54. Write a Pandas program to read rows in which the 'cut' is 'Premium', column 'color' of diamonds DataFrame.

# %%
df[df['cutDiamond']== 'Premium'][['cutDiamond','color']]
# Out:
#       cutDiamond color
# 1        Premium     E
# 3        Premium     I
# 12       Premium     F
# 14       Premium     E
# 15       Premium     E
# ...          ...   ...
# 53918    Premium     I
# 53928    Premium     E
# 53930    Premium     E
# 53931    Premium     F
# 53934    Premium     D
#
# [13790 rows x 2 columns]

# %% [markdown]
# ### 55. Write a Pandas program to read rows in positions 0 and 1, columns in positions 0 and 3 of diamonds DataFrame.

# %%
df.iloc[[0,1],[0,3]]
# Out:
#    carat  price
# 0   0.23    326
# 1   0.21    326

# %% [markdown]
# ### 56. Write a Pandas program to read rows in positions 0 through 4, columns in positions 1 through 4 of diamonds DataFrame.

# %%
df.iloc[0:5,1:5]
# Out:
#   cutDiamond clarity  price     x
# 0      Ideal     SI2    326  3.95
# 1    Premium     SI1    326  3.89
# 2       Good     VS1    327  4.05
# 3    Premium     VS2    334  4.20
# 4       Good     SI2    335  4.34

# %% [markdown]
# ### 57. Write a Pandas program to read rows in positions 0 through 4 (exclusive) and all columns of diamonds DataFrame.

# %%
df.iloc[0:4]
# Out:
#    carat cutDiamond clarity  price     x     y     z  priceUpdated  \
# 0   0.23      Ideal     SI2    326  3.95  3.98  2.43         358.6
# 1   0.21    Premium     SI1    326  3.89  3.84  2.31         358.6
# 2   0.23       Good     VS1    327  4.05  4.07  2.31         359.7
# 3   0.29    Premium     VS2    334  4.20  4.23  2.63         367.4
#
#   Quality - color     volume color
# 0       Ideal - E  38.202030     E
# 1     Premium - E  34.505856     E
# 2        Good - E  38.076885     E
# 3     Premium - I  46.724580     I

# %% [markdown]
# ### 58. Write a Pandas program to read rows 2 through 5 (inclusive), columns in positions 0 through 2 (exclusive) of diamonds DataFrame.

# %%
df.iloc[2:6,0:3]
# Out:
#    carat cutDiamond clarity
# 2   0.23       Good     VS1
# 3   0.29    Premium     VS2
# 4   0.31       Good     SI2
# 5   0.24  Very Good    VVS2

# %% [markdown]
# ### 59. Write a Pandas program to print a concise summary of diamonds DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53938 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   carat            53938 non-null  float64
#  1   cutDiamond       53938 non-null  object
#  2   clarity          53938 non-null  object
#  3   price            53938 non-null  int64
#  4   x                53938 non-null  float64
#  5   y                53938 non-null  float64
#  6   z                53938 non-null  float64
#  7   priceUpdated     53938 non-null  float64
#  8   Quality - color  53938 non-null  object
#  9   volume           53938 non-null  float64
#  10  color            53938 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 7.0+ MB

# %% [markdown]
# ### 60. Write a Pandas program to get the true memory usage by diamonds DataFrame.

# %%
# Get the true memory usage of the DataFrame
memory_usage = df.memory_usage(deep=True)

# Print the memory usage
print(memory_usage)
print(f'Total memory usage: {memory_usage.sum()} bytes')
# Out:
# Index              2545080
# carat               431504
# cutDiamond         3413544
# clarity            3242470
# price               431504
# x                   431504
# y                   431504
# z                   431504
# priceUpdated        431504
# Quality - color    3629296
# volume              431504
# color              3128404
# dtype: int64
# Total memory usage: 18979322 bytes

# %% [markdown]
# ### 61. Write a Pandas program to calculate the memory usage for each Series (in bytes) of diamonds DataFrame.

# %%
memory_usage = df.memory_usage(deep=True)

# Print the memory usage for each Series
print("Memory usage for each Series (in bytes):")
print(memory_usage)

# Optionally, print the total memory usage
total_memory = memory_usage.sum()
print(f'\nTotal memory usage: {total_memory} bytes')
# Out:
# Memory usage for each Series (in bytes):
# Index              2545080
# carat               431504
# cutDiamond         3413544
# clarity            3242470
# price               431504
# x                   431504
# y                   431504
# z                   431504
# priceUpdated        431504
# Quality - color    3629296
# volume              431504
# color              3128404
# dtype: int64
#
# Total memory usage: 18979322 bytes

# %% [markdown]
# ### 62. Write a Pandas program to get randomly sample rows from diamonds DataFrame.

# %%
import numpy as np

# np.random.seed(34)
sampled_rows = df.sample(n=5)

sampled_rows
# Out:
#        carat cutDiamond clarity  price     x     y     z  priceUpdated  \
# 23190   1.29      Ideal     VS1  11197  7.08  7.05  4.29       12316.7
# 48578   0.54      Ideal     VS2   1993  5.29  5.25  3.22        2192.3
# 14799   1.20  Very Good     VS2   5955  6.76  6.81  4.23        6550.5
# 11308   1.06    Premium     SI1   4984  6.57  6.61  4.02        5482.4
# 28662   0.31      Ideal    VVS2    677  4.37  4.40  2.74         744.7
#
#       Quality - color      volume color
# 23190       Ideal - F  214.131060     F
# 48578       Ideal - D   89.427450     D
# 14799   Very Good - I  194.730588     I
# 11308     Premium - H  174.579354     H
# 28662       Ideal - G   52.684720     G

# %% [markdown]
# ### 63. Write a Pandas program to get sample 75% of the diamonds DataFrame's rows without replacement and store the remaining 25% of the rows in another DataFrame.

# %%
df.info()
df.iloc[0:int(len(df)*(3/4))]
data = df.iloc[int(len(df)*(3/4)):]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53938 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   carat            53938 non-null  float64
#  1   cutDiamond       53938 non-null  object
#  2   clarity          53938 non-null  object
#  3   price            53938 non-null  int64
#  4   x                53938 non-null  float64
#  5   y                53938 non-null  float64
#  6   z                53938 non-null  float64
#  7   priceUpdated     53938 non-null  float64
#  8   Quality - color  53938 non-null  object
#  9   volume           53938 non-null  float64
#  10  color            53938 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 7.0+ MB

# %%
data
# Out:
#        carat cutDiamond clarity  price     x     y     z  priceUpdated  \
# 40453   0.31      Ideal    VVS1   1140  4.44  4.41  2.68        1254.0
# 40454   0.32      Ideal    VVS1   1140  4.43  4.45  2.73        1254.0
# 40455   0.50      Ideal     SI1   1140  5.07  5.09  3.16        1254.0
# 40456   0.50      Ideal     SI1   1140  5.07  5.09  3.17        1254.0
# 40457   0.50      Ideal     SI1   1140  5.04  5.07  3.14        1254.0
# ...      ...        ...     ...    ...   ...   ...   ...           ...
# 53933   0.70  Very Good     VS2   2757  5.69  5.72  3.49        3032.7
# 53934   0.72    Premium     SI1   2757  5.69  5.73  3.58        3032.7
# 53935   0.72      Ideal     SI1   2757  5.75  5.76  3.50        3032.7
# 53936   0.72       Good     SI1   2757  5.69  5.75  3.61        3032.7
# 53939   0.75      Ideal     SI2   2757  5.83  5.87  3.64        3032.7
#
#       Quality - color      volume color
# 40453       Ideal - F   52.475472     F
# 40454       Ideal - E   53.817855     E
# 40455       Ideal - H   81.547908     H
# 40456       Ideal - H   81.805971     H
# 40457       Ideal - H   80.235792     H
# ...               ...         ...   ...
# 53933   Very Good - E  113.588332     E
# 53934     Premium - D  116.721246     D
# 53935       Ideal - D  115.920000     D
# 53936        Good - D  118.110175     D
# 53939       Ideal - D  124.568444     D
#
# [13485 rows x 11 columns]

# %% [markdown]
# ### 64. Write a Pandas program to read the diamonds DataFrame and detect duplicate color. Note: duplicated () function returns boolean Series denoting duplicate rows, optionally only considering certain columns

# %%
duplicate_rows = df.duplicated('color')
df = df[duplicate_rows]
df
# Out:
#        carat cutDiamond clarity  price     x     y     z  priceUpdated  \
# 1       0.21    Premium     SI1    326  3.89  3.84  2.31         358.6
# 2       0.23       Good     VS1    327  4.05  4.07  2.31         359.7
# 5       0.24  Very Good    VVS2    336  3.94  3.96  2.48         369.6
# 6       0.24  Very Good    VVS1    336  3.95  3.98  2.47         369.6
# 8       0.22       Fair     VS2    337  3.87  3.78  2.49         370.7
# ...      ...        ...     ...    ...   ...   ...   ...           ...
# 53933   0.70  Very Good     VS2   2757  5.69  5.72  3.49        3032.7
# 53934   0.72    Premium     SI1   2757  5.69  5.73  3.58        3032.7
# 53935   0.72      Ideal     SI1   2757  5.75  5.76  3.50        3032.7
# 53936   0.72       Good     SI1   2757  5.69  5.75  3.61        3032.7
# 53939   0.75      Ideal     SI2   2757  5.83  5.87  3.64        3032.7
#
#       Quality - color      volume color
# 1         Premium - E   34.505856     E
# 2            Good - E   38.076885     E
# 5       Very Good - J   38.693952     J
# 6       Very Good - I   38.830870     I
# 8            Fair - E   36.425214     E
# ...               ...         ...   ...
# 53933   Very Good - E  113.588332     E
# 53934     Premium - D  116.721246     D
# 53935       Ideal - D  115.920000     D
# 53936        Good - D  118.110175     D
# 53939       Ideal - D  124.568444     D
#
# [53931 rows x 11 columns]

# %% [markdown]
# ### 65. Write a Pandas program to count the duplicate rows of diamonds DataFrame.

# %%
duplicate_count = df.duplicated().sum()
duplicate_count
# Out:
# 296

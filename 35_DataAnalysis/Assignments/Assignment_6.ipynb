# %% [markdown]
# <center><b><h1>Assignment_6</h1></b></center>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv('./DataSet/alphabet_stock_data.csv')
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# ...

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>1. Write a Pandas program to create a line plot of the historical stock prices of
# Alphabet Inc. between two specific dates.</b>
# </div>

# %%
start_date = '2020-04-01'
end_date = '2020-05-03'

plt.figure(figsize=(18,8))

filtered_date = df[(df['Date']>=start_date) & (df['Date']<=end_date)]
plt.plot(filtered_date['Date'],filtered_date['Close'],ls='--',c='b',marker='o',label='Closing Price')
plt.xticks(rotation= 90)
plt.xlabel('Dates',fontsize=15,c='red',labelpad=15)
plt.ylabel('Closing Price',fontsize=15,c='red',labelpad=15)
plt.title('Line plot of the historical stock prices btn two specific dates',fontsize=25,c='green',pad=10)
plt.grid(True)
plt.legend(fontsize=15,loc='lower right')
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>2. Write a Pandas program to create a line plot of the opening, closing stock
# prices of Alphabet Inc. between two specific dates.</b>
# </div>

# %%
start_date = '2020-04-01'
end_date = '2020-05-03'

plt.figure(figsize=(18,8))

filtered_date = df[(df['Date']>=start_date) & (df['Date']<=end_date)]
plt.plot(filtered_date['Date'],filtered_date['Close'],ls='--',c='r',marker='o',label='Closing Price')
plt.plot(filtered_date['Date'],filtered_date['Open'],ls=':',c='g',marker='.',label='Opening Price')
plt.xticks(rotation= 90)
plt.xlabel('Dates',fontsize=15,c='red',labelpad=15)
plt.ylabel('Price',fontsize=15,c='red',labelpad=15)
plt.title('Line plot of the Closing and Opening price of historical stock price btn two specific dates',fontsize=25,c='green',pad=10)
plt.grid(True)
plt.legend(fontsize=15,loc='lower right')
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>3. Write a Pandas program to create a bar plot of the trading volume of Alphabet
# Inc. stock between two specific dates.</b>
# </div>

# %%
start_date = '2020-04-01'
end_date = '2020-05-03'

plt.figure(figsize=(18,8))

filtered_date = df[(df['Date']>=start_date) & (df['Date']<=end_date)]
plt.bar(filtered_date['Date'],filtered_date['Volume'],ls='--',color='pink',label='Volume')

plt.xticks(rotation= 90)
plt.xlabel('Dates',fontsize=15,c='red',labelpad=15)
plt.ylabel('Volume',fontsize=15,c='red',labelpad=15)
plt.title('Bar plot of the trading volume',fontsize=25,c='green',pad=10)
plt.grid(True)
plt.legend(fontsize=15,loc='upper left')
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>4. Write a Pandas program to create a bar plot of opening, closing stock prices of
# Alphabet Inc. between two specific dates.</b>
# </div>

# %%
start_date = '2020-04-01'
end_date = '2020-05-03'

plt.figure(figsize=(18,8))

filtered_date = df[(df['Date']>=start_date) & (df['Date']<=end_date)]
x = np.arange(len(filtered_date['Date']))

bar_width = 0.4
plt.bar(x - bar_width/2, filtered_date['Open'], width = bar_width, color='#FF7F50', label='Opening Price')
plt.bar(x + bar_width/2, filtered_date['Close'], width = bar_width, color='#00BFFF', label='Closing Price')

plt.xticks(rotation= 90)
plt.xlabel('Dates',fontsize=15,c='red',labelpad=15)
plt.ylabel('Price',fontsize=15,c='red',labelpad=15)
plt.title('Bar plot of opening, closing stock prices of Alphabet' ,fontsize=25,pad=10)

plt.xticks(x + bar_width / 2, filtered_date['Date'])
plt.legend(fontsize=15,loc='upper left')
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>5. Write a Pandas program to create a stacked bar plot of opening, closing stock
# prices of Alphabet Inc. between two specific dates.</b>
# </div>

# %%
start_date = '2020-04-01'
end_date = '2020-05-03'

plt.figure(figsize=(18,8))

filtered_date = df[(df['Date']>=start_date) & (df['Date']<=end_date)]
x = np.arange(len(filtered_date['Date']))


plt.bar(x , filtered_date['Open'],  color='#FF7F50', label='Opening Price')
plt.bar(x , filtered_date['Close'],bottom=filtered_date['Open'], color='#008080', label='Closing Price')

plt.xticks(rotation= 90)
plt.xlabel('Dates',fontsize=15,c='red',labelpad=15)
plt.ylabel('Price',fontsize=15,c='red',labelpad=15)
plt.title('Bar plot of opening, closing stock prices of Alphabet' ,fontsize=25,pad=10)

plt.xticks(x + bar_width / 2, filtered_date['Date'])
plt.legend(fontsize=15,loc='upper left')
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>6. Write a Pandas program to create a horizontal stacked bar plot of opening,
# closing stock prices of Alphabet Inc. between two specific dates.</b>
# </div>

# %%
start_date = '2020-04-01'
end_date = '2020-04-29'

plt.figure(figsize=(15,12))

filtered_date = df[(df['Date']>=start_date) & (df['Date']<=end_date)]
x = np.arange(len(filtered_date['Date']))


plt.barh(x,filtered_date['Open'],  color='#FF7F50', label='Opening Price')
plt.barh(x,filtered_date['Close'], left=filtered_date['Open'],color='#008080', label='Closing Price')

plt.xticks(rotation= 90)
plt.xlabel('Prices',fontsize=15,c='red',labelpad=15)
plt.ylabel('date',fontsize=15,c='red',labelpad=15)
plt.title('Bar plot of opening, closing stock prices of Alphabet' ,fontsize=25,pad=10)

plt.yticks(x + bar_width / 2, filtered_date['Date'])
plt.legend(fontsize=15,loc='lower right')
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>7. Write a Pandas program to create a histograms plot of opening, closing, high,
# low stock prices of Alphabet Inc. between two specific dates.</b>
# </div>

# %%
plt.figure(figsize=(12, 8))

start_date = '2020-04-01'
end_date = '2020-04-20'

filtered_date = df[(df['Date']>=start_date) & (df['Date']<=end_date)]
x = np.arange(len(filtered_date['Date']))

# Opening prices
plt.subplot(2, 2, 1)
plt.hist(filtered_date['Open'], bins=10, color='blue', alpha=0.7)

# Closing prices
plt.subplot(2, 2, 1)
plt.hist(filtered_date['Close'], bins=10, color='green', alpha=0.5)

# High prices
plt.subplot(2, 2, 1)
plt.hist(filtered_date['High'], bins=10, color='orange', alpha=0.4)

# Low prices
plt.subplot(2, 2, 1)
plt.hist(filtered_date['Low'], bins=10, color='red', alpha=0.2)
plt.yticks(x + bar_width / 2, filtered_date['Date'])
plt.title('Histogram plot for Open, Close, High, Low ')
plt.xlabel('Price')
plt.ylabel('Date')

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>8. Write a Pandas program to create a stacked histograms plot of opening,
# closing, high, low stock prices of Alphabet Inc. between two specific dates.</b>
# </div>

# %%
# Prepare data for stacking
prices = pd.DataFrame({
    'Open': filtered_date['Open'],
    'Close': filtered_date['Close'],
    'High': filtered_date['High'],
    'Low': filtered_date['Low']
})
x = np.arange(len(filtered_date['Date']))
# Plotting stacked histogram
plt.figure(figsize=(12, 8))

# Use hist with the stacked parameter
prices.plot.hist(stacked=True, bins=10, alpha=0.7)

# Adding titles and labels
plt.title('Stacked Histogram of Stock Prices for Alphabet Inc.')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.yticks(x + bar_width / 2, filtered_date['Date'])
plt.legend(title='Price')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>9. Write a Pandas program to draw a horizontal and cumulative histograms plot
# of opening stock prices of Alphabet Inc. between two specific dates.
# </b>
# </div>

# %%
# Prepare data for stacking
prices = pd.DataFrame({
    'Open': filtered_date['Open'],
})

# Plotting stacked histogram
plt.figure(figsize=(12, 8))

# Use hist with the stacked parameter
prices.plot.hist(orientation = "horizontal",cumulative=True)

# Adding titles and labels
plt.title('Cumulative Histogram of Stock Prices for Alphabet Inc.')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# <div class = "alert alert-block alert-info"
#     <b>10. Write a Pandas program to create a stacked histograms plot of opening,
# closing, high, low stock prices of Alphabet Inc. between two specific dates with
# more bins.</b>
# </div>

# %%
start_date = '2020-04-01'
end_date = '2020-05-29'

filtered_date = df[(df['Date']>=start_date) & (df['Date']<=end_date)]
x = np.arange(len(filtered_date['Date']))

# Prepare data for stacking
prices = pd.DataFrame({
    'Open': filtered_date['Open'],
    'Close': filtered_date['Close'],
    'High': filtered_date['High'],
    'Low': filtered_date['Low']
})

# Plotting stacked histogram
plt.figure(figsize=(12, 8))

# Use hist with the stacked parameter
prices.plot.hist(stacked=True,bins=400)

# Adding titles and labels
plt.title('Cumulative Histogram of Stock Prices for Alphabet Inc.')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.show()

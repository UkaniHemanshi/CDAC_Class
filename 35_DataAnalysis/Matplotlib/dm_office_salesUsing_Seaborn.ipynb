# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv("dm_office_sales.csv")
df.head(6)
# Out:
#             division  level of education  training level  work experience  \
# 0           printers        some college               2                6
# 1           printers  associate's degree               2               10
# 2        peripherals         high school               0                9
# 3    office supplies  associate's degree               2                5
# 4    office supplies         high school               1                5
# 5  computer hardware        some college               0               10
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802
# 5  102401  366451

# %%
## countplot: A simple plot, it merely shows the total count of rows per category
# histogram across a categorical, instead of quantitative, variable

plt.figure(figsize =(9,5),dpi = 80) #dpi = Dots per Inch of space
sns.countplot(x="division",data= df)
plt.show()

# %%
plt.figure(figsize =(9,5),dpi = 80) #dpi = Dots per Inch of space
sns.countplot(x="level of education",data= df)
plt.show()

# %%
# Breakdown within another category with 'hue'
plt.figure(figsize =(9,5),dpi = 80) #dpi = Dots per Inch of space
sns.countplot(x="level of education",data= df,hue = "training level")
plt.show()

# %%
# using palette
plt.figure(figsize =(9,5),dpi = 80) #dpi = Dots per Inch of space
sns.countplot(x="level of education",data= df,hue = "training level",palette = "Set1")
plt.show()

# %%
import pandas as pd
import datetime
import numpy as np
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv("MS_Dhoni_ODI_record.csv")
df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes     opposition  \
# 0       0           0           1           0     0     0   v Bangladesh
# 1      12          12          11      109.09     2     0   v Bangladesh
# 2      7*           7           2         350     0     1   v Bangladesh
# 3       3           3           7       42.85     0     0     v Pakistan
# 4     148         148         123      120.32    15     4     v Pakistan
# ..    ...         ...         ...         ...   ...   ...            ...
# 345   56*          56          61        91.8     3     2  v West Indies
# 346   42*          42          31      135.48     4     1      v England
# 347    35          35          33      106.06     4     0   v Bangladesh
# 348   DNB           -           -           -     -     -    v Sri Lanka
# 349    50          50          72       69.44     1     1  v New Zealand
#
#             ground        date  odi_number
# 0       Chattogram  23/12/2004  ODI # 2199
# ...

# %%
df.head()
# Out:
#   score runs_scored balls_faced strike_rate fours sixes    opposition  \
# 0     0           0           1           0     0     0  v Bangladesh
# 1    12          12          11      109.09     2     0  v Bangladesh
# 2    7*           7           2         350     0     1  v Bangladesh
# 3     3           3           7       42.85     0     0    v Pakistan
# 4   148         148         123      120.32    15     4    v Pakistan
#
#           ground        date  odi_number
# 0     Chattogram  23/12/2004  ODI # 2199
# 1          Dhaka  26/12/2004  ODI # 2201
# 2          Dhaka  27/12/2004  ODI # 2202
# 3          Kochi  02/04/2005  ODI # 2235
# 4  Visakhapatnam  05/04/2005  ODI # 2236

# %%
df.tail()
# Out:
#     score runs_scored balls_faced strike_rate fours sixes     opposition  \
# 345   56*          56          61        91.8     3     2  v West Indies
# 346   42*          42          31      135.48     4     1      v England
# 347    35          35          33      106.06     4     0   v Bangladesh
# 348   DNB           -           -           -     -     -    v Sri Lanka
# 349    50          50          72       69.44     1     1  v New Zealand
#
#          ground        date  odi_number
# 345  Manchester  27/06/2019  ODI # 4175
# 346  Birmingham  30/06/2019  ODI # 4179
# 347  Birmingham  02/07/2019  ODI # 4182
# 348       Leeds  06/07/2019  ODI # 4187
# 349  Manchester  09/07/2019  ODI # 4190

# %%
# replace v in opposition  [Data cleaning ]

# df['opposition'] = df['opposition'].str.replace('v','',regex=False) # method1
df['opposition'] =df['opposition'].apply(lambda x: x[2:])  # method2

# %%
df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0       0           0           1           0     0     0   Bangladesh
# 1      12          12          11      109.09     2     0   Bangladesh
# 2      7*           7           2         350     0     1   Bangladesh
# 3       3           3           7       42.85     0     0     Pakistan
# 4     148         148         123      120.32    15     4     Pakistan
# ..    ...         ...         ...         ...   ...   ...          ...
# 345   56*          56          61        91.8     3     2  West Indies
# 346   42*          42          31      135.48     4     1      England
# 347    35          35          33      106.06     4     0   Bangladesh
# 348   DNB           -           -           -     -     -    Sri Lanka
# 349    50          50          72       69.44     1     1  New Zealand
#
#             ground        date  odi_number
# 0       Chattogram  23/12/2004  ODI # 2199
# ...

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst= True)  
df['Year'] = df['date'].dt.year.astype(int)

df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0       0           0           1           0     0     0   Bangladesh
# 1      12          12          11      109.09     2     0   Bangladesh
# 2      7*           7           2         350     0     1   Bangladesh
# 3       3           3           7       42.85     0     0     Pakistan
# 4     148         148         123      120.32    15     4     Pakistan
# ..    ...         ...         ...         ...   ...   ...          ...
# 345   56*          56          61        91.8     3     2  West Indies
# 346   42*          42          31      135.48     4     1      England
# 347    35          35          33      106.06     4     0   Bangladesh
# 348   DNB           -           -           -     -     -    Sri Lanka
# 349    50          50          72       69.44     1     1  New Zealand
#
#             ground       date  odi_number  Year
# 0       Chattogram 2004-12-23  ODI # 2199  2004
# ...

# %%
df.Year  # or df['Year']
# Out:
# 0      2004
# 1      2004
# 2      2004
# 3      2005
# 4      2005
#        ...
# 345    2019
# 346    2019
# 347    2019
# 348    2019
# 349    2019
# Name: Year, Length: 350, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   score        350 non-null    object
#  1   runs_scored  350 non-null    object
#  2   balls_faced  350 non-null    object
#  3   strike_rate  350 non-null    object
#  4   fours        350 non-null    object
#  5   sixes        350 non-null    object
#  6   opposition   350 non-null    object
#  7   ground       350 non-null    object
#  8   date         350 non-null    datetime64[ns]
#  9   odi_number   350 non-null    object
#  10  Year         350 non-null    int32
# dtypes: datetime64[ns](1), int32(1), object(9)
# memory usage: 28.8+ KB

# %%
df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0       0           0           1           0     0     0   Bangladesh
# 1      12          12          11      109.09     2     0   Bangladesh
# 2      7*           7           2         350     0     1   Bangladesh
# 3       3           3           7       42.85     0     0     Pakistan
# 4     148         148         123      120.32    15     4     Pakistan
# ..    ...         ...         ...         ...   ...   ...          ...
# 345   56*          56          61        91.8     3     2  West Indies
# 346   42*          42          31      135.48     4     1      England
# 347    35          35          33      106.06     4     0   Bangladesh
# 348   DNB           -           -           -     -     -    Sri Lanka
# 349    50          50          72       69.44     1     1  New Zealand
#
#             ground       date  odi_number  Year
# 0       Chattogram 2004-12-23  ODI # 2199  2004
# ...

# %%
# batting avg = total runs scored /(Innigs count - not outs count)

df['score'] = df['score'].apply(str)
df['not_out'] = np.where(df['score'].str.endswith('*'),1,0)
df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0       0           0           1           0     0     0   Bangladesh
# 1      12          12          11      109.09     2     0   Bangladesh
# 2      7*           7           2         350     0     1   Bangladesh
# 3       3           3           7       42.85     0     0     Pakistan
# 4     148         148         123      120.32    15     4     Pakistan
# ..    ...         ...         ...         ...   ...   ...          ...
# 345   56*          56          61        91.8     3     2  West Indies
# 346   42*          42          31      135.48     4     1      England
# 347    35          35          33      106.06     4     0   Bangladesh
# 348   DNB           -           -           -     -     -    Sri Lanka
# 349    50          50          72       69.44     1     1  New Zealand
#
#             ground       date  odi_number  Year  not_out
# 0       Chattogram 2004-12-23  ODI # 2199  2004        0
# ...

# %%
df.drop(columns='odi_number',inplace=True)

# %%
df
# Out:
#     score runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0       0           0           1           0     0     0   Bangladesh
# 1      12          12          11      109.09     2     0   Bangladesh
# 2      7*           7           2         350     0     1   Bangladesh
# 3       3           3           7       42.85     0     0     Pakistan
# 4     148         148         123      120.32    15     4     Pakistan
# ..    ...         ...         ...         ...   ...   ...          ...
# 345   56*          56          61        91.8     3     2  West Indies
# 346   42*          42          31      135.48     4     1      England
# 347    35          35          33      106.06     4     0   Bangladesh
# 348   DNB           -           -           -     -     -    Sri Lanka
# 349    50          50          72       69.44     1     1  New Zealand
#
#             ground       date  Year  not_out
# 0       Chattogram 2004-12-23  2004        0
# ...

# %%
df_new = df.loc[((df['score']!='DNB') & (df['score'] != "TDNB")),'runs_scored':]
df_new
# Out:
#     runs_scored balls_faced strike_rate fours sixes   opposition  \
# 0             0           1           0     0     0   Bangladesh
# 1            12          11      109.09     2     0   Bangladesh
# 2             7           2         350     0     1   Bangladesh
# 3             3           7       42.85     0     0     Pakistan
# 4           148         123      120.32    15     4     Pakistan
# ..          ...         ...         ...   ...   ...          ...
# 344          28          52       53.84     3     0  Afghanistan
# 345          56          61        91.8     3     2  West Indies
# 346          42          31      135.48     4     1      England
# 347          35          33      106.06     4     0   Bangladesh
# 349          50          72       69.44     1     1  New Zealand
#
#             ground       date  Year  not_out
# 0       Chattogram 2004-12-23  2004        0
# 1            Dhaka 2004-12-26  2004        0
# 2            Dhaka 2004-12-27  2004        1
# ...

# %%
# fixing the data types of numerical columns
df_new.info()
df_new['runs_scored'] =df_new['runs_scored'].astype(int)
df_new['balls_faced'] =df_new['balls_faced'].astype(int)
df_new['strike_rate'] =df_new['strike_rate'].astype(float)
df_new['fours'] =df_new['fours'].astype(int)
df_new['sixes'] =df_new['sixes'].astype(int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 349
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   runs_scored  297 non-null    object
#  1   balls_faced  297 non-null    object
#  2   strike_rate  297 non-null    object
#  3   fours        297 non-null    object
#  4   sixes        297 non-null    object
#  5   opposition   297 non-null    object
#  6   ground       297 non-null    object
#  7   date         297 non-null    datetime64[ns]
#  8   Year         297 non-null    int32
#  9   not_out      297 non-null    int32
# dtypes: datetime64[ns](1), int32(2), object(7)
# memory usage: 23.2+ KB

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 349
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   runs_scored  297 non-null    int32
#  1   balls_faced  297 non-null    int32
#  2   strike_rate  297 non-null    float64
#  3   fours        297 non-null    int32
#  4   sixes        297 non-null    int32
#  5   opposition   297 non-null    object
#  6   ground       297 non-null    object
#  7   date         297 non-null    datetime64[ns]
#  8   Year         297 non-null    int32
#  9   not_out      297 non-null    int32
# dtypes: datetime64[ns](1), float64(1), int32(6), object(2)
# memory usage: 18.6+ KB

# %%
# career states

first_match_date = df['date'].dt.date.min().strftime('%B %d, %Y')
print(first_match_date)

last_match_date = df['date'].dt.date.max().strftime('%B %d, %Y')
print(last_match_date)
# Out:
# December 23, 2004
# July 09, 2019

# %%
numOfmatches = df.shape[0]
print(f"Number of matches : {numOfmatches}")

numOfinnings = df_new.shape[0]
print(f"Number of innings : {numOfinnings}")

not_outs = df_new['not_out'].sum()
print(f"Number of innings : {not_outs}")

runs_scored = df_new['runs_scored'].sum()
print(f"runs_scored : {runs_scored}")

balls_faced   = df_new['balls_faced'].sum()
print(f"balls_faced   : {balls_faced}")
# Out:
# Number of matches : 350
# Number of innings : 297
# Number of innings : 84
# runs_scored : 10773
# balls_faced   : 12303

# %%
# batting avg = total runs scored /(Innigs count - not outs count)
career_sk = runs_scored / balls_faced  
print("Career strike: {:.2f}".format(career_sk))

career_avg = runs_scored /(numOfinnings - not_outs )
print("Career avg: {:.2f}".format(career_avg))
# Out:
# Career strike: 0.88
# Career avg: 50.58

# %%
hundread = (df_new['runs_scored']>100).sum()
print(hundread)

fifites = ((df_new))
# Out:
# 10

# %% [markdown]
# ##  visualization

# %%
df_new
# Out:
#      runs_scored  balls_faced  strike_rate  fours  sixes   opposition  \
# 0              0            1         0.00      0      0   Bangladesh
# 1             12           11       109.09      2      0   Bangladesh
# 2              7            2       350.00      0      1   Bangladesh
# 3              3            7        42.85      0      0     Pakistan
# 4            148          123       120.32     15      4     Pakistan
# ..           ...          ...          ...    ...    ...          ...
# 344           28           52        53.84      3      0  Afghanistan
# 345           56           61        91.80      3      2  West Indies
# 346           42           31       135.48      4      1      England
# 347           35           33       106.06      4      0   Bangladesh
# 349           50           72        69.44      1      1  New Zealand
#
#             ground       date  Year  not_out
# 0       Chattogram 2004-12-23  2004        0
# ...

# %%
opposition_count = df['opposition'].value_counts()
print(opposition_count)
# Out:
# opposition
# Sri Lanka       67
# Australia       55
# England         48
# West Indies     39
# South Africa    37
# Pakistan        36
# New Zealand     28
# Bangladesh      21
# Zimbabwe         6
# Africa XI        3
# Hong Kong        2
# Ireland          2
# Afghanistan      2
# Bermuda          1
# Scotland         1
# Netherlands      1
# U.A.E.           1
# Name: count, dtype: int64

# %%
# bar plot for (opposition , opposition_count)
import matplotlib.pyplot as plt
opposition_count.plot(kind = "bar",title = 'Number of macthes against different ',figsize =(8,5))
plt.show()

# %%
# runs scored against mach team 

# group the dataframe by 'opposition' column 

group_Byopposition = df_new.groupby('opposition')
sum_of_numsScored = group_Byopposition['runs_scored'].sum()
print(sum_of_numsScored)
# Out:
# opposition
# Afghanistan       36
# Africa XI        174
# Australia       1660
# Bangladesh       569
# Bermuda           29
# England         1546
# Hong Kong        109
# Ireland           34
# Netherlands       19
# New Zealand      940
# Pakistan        1231
# South Africa     830
# Sri Lanka       2383
# West Indies     1005
# Zimbabwe         208
# Name: runs_scored, dtype: int32

# %%
runs_scored_by_opposition = pd.DataFrame(sum_of_numsScored).reset_index()
runs_scored_by_opposition
# Out:
#       opposition  runs_scored
# 0    Afghanistan           36
# 1      Africa XI          174
# 2      Australia         1660
# 3     Bangladesh          569
# 4        Bermuda           29
# 5        England         1546
# 6      Hong Kong          109
# 7        Ireland           34
# 8    Netherlands           19
# 9    New Zealand          940
# 10      Pakistan         1231
# 11  South Africa          830
# 12     Sri Lanka         2383
# 13   West Indies         1005
# 14      Zimbabwe          208

# %%
runs_scored_by_opposition.plot(x='opposition',kind='bar',title="Runs scored against different opposition", figsize=(8,5))
plt.xlabel(None);
plt.show()

# %% [markdown]
# ## Using Sns

# %%
import seaborn as sns

# %%
plt.figure(figsize =(17,10),dpi = 120)
sns.boxplot(x = 'opposition',y = "runs_scored", data=df_new)
plt.show()

# %%
runs_scored_by_opposition
# Out:
#       opposition  runs_scored
# 0    Afghanistan           36
# 1      Africa XI          174
# 2      Australia         1660
# 3     Bangladesh          569
# 4        Bermuda           29
# 5        England         1546
# 6      Hong Kong          109
# 7        Ireland           34
# 8    Netherlands           19
# 9    New Zealand          940
# 10      Pakistan         1231
# 11  South Africa          830
# 12     Sri Lanka         2383
# 13   West Indies         1005
# 14      Zimbabwe          208

# %%
# filter rows where 'opposition' is in the list

opposition_lst = ['England','Australia','West Indies','South Africa','New Zealand','Pakistan','Sri Lanka','Bangladesh']
df_filtered = df_new[df_new['opposition'].isin(opposition_lst)]

# %%
# sort the filtered  DataFrame in descending order of 'runs_scored'
df_filtered = df_filtered.sort_values(by='runs_scored',ascending=False)
df_filtered
# Out:
#      runs_scored  balls_faced  strike_rate  fours  sixes    opposition  \
# 21           183          145       126.20     15     10     Sri Lanka
# 4            148          123       120.32     15      4      Pakistan
# 228          139          121       114.87     12      5     Australia
# 284          134          122       109.83     10      6       England
# 146          124          107       115.88      9      3     Australia
# ..           ...          ...          ...    ...    ...           ...
# 74             0            4         0.00      0      0  South Africa
# 273            0            3         0.00      0      0     Australia
# 171            0            1         0.00      0      0     Australia
# 223            0            4         0.00      0      0       England
# 0              0            1         0.00      0      0    Bangladesh
#
#             ground       date  Year  not_out
# 21          Jaipur 2005-10-31  2005        1
# ...

# %%
sns.boxplot(x='opposition',y='runs_scored',data=df_filtered)
plt.xticks(rotation=45)
plt.show()

# %%
sns.displot(data=df_filtered,x='runs_scored',kde=False)
plt.show()

# %%
sns.displot(data=df_filtered,x='runs_scored',kde=True)
plt.show()

# %%
# histogram with bins

sns.set(style="darkgrid")
sns.histplot(data= df_new,x = 'runs_scored',bins =10)
plt.show()

# %% [markdown]
# ## KDE plot

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(data = df_new,x = "runs_scored")
plt.show()

# %% [markdown]
# ## KDE plot with cumulative probability

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(data = df_new,x = "runs_scored",cumulative = True)
plt.show()

# %% [markdown]
# ## Jointplot

# %%
sns.jointplot(x="balls_faced",y = "runs_scored",data=df_new,kind= "scatter")
plt.show()

# %% [markdown]
# ## Heat map

# %%
correlation_matrix = df_new[['balls_faced','runs_scored']].corr()
plt.figure(figsize=(8,6))

sns.heatmap(data=correlation_matrix,annot=True,cmap ='viridis',square=True,fmt=".2f")
plt.title('Correlation heatmap btn Balls Faced and Runs Scored')
plt.show()

# %%
df_new
# Out:
#      runs_scored  balls_faced  strike_rate  fours  sixes   opposition  \
# 0              0            1         0.00      0      0   Bangladesh
# 1             12           11       109.09      2      0   Bangladesh
# 2              7            2       350.00      0      1   Bangladesh
# 3              3            7        42.85      0      0     Pakistan
# 4            148          123       120.32     15      4     Pakistan
# ..           ...          ...          ...    ...    ...          ...
# 344           28           52        53.84      3      0  Afghanistan
# 345           56           61        91.80      3      2  West Indies
# 346           42           31       135.48      4      1      England
# 347           35           33       106.06      4      0   Bangladesh
# 349           50           72        69.44      1      1  New Zealand
#
#             ground       date  Year  not_out
# 0       Chattogram 2004-12-23  2004        0
# ...

# %%
# Assuming df_new is your DataFrame and it has a 'strike_rate' column.
plt.figure(figsize=(10, 6))

# Group by 'opposition' and sum the 'strike_rate'
sum_strikeRate = df_filtered.groupby('opposition')['strike_rate'].median().reset_index()

# Pivot the data for heatmap
heatmap_data = sum_strikeRate.set_index('opposition')
print(heatmap_data)

# Create the heatmap
sns.heatmap(data=heatmap_data, annot=True, cmap='viridis', square=False)

plt.title('Sum of Strike Rates by Opposition')
plt.xlabel('Strike Rate')
plt.ylabel('Opposition')
plt.show()
# Out:
#               strike_rate
# opposition
# Australia          76.085
# Bangladesh         85.840
# England            86.900
# New Zealand        76.410
# Pakistan           79.160
# South Africa       83.345
# Sri Lanka          80.000
# West Indies        91.800

# %%
df_new
# Out:
#      runs_scored  balls_faced  strike_rate  fours  sixes   opposition  \
# 0              0            1         0.00      0      0   Bangladesh
# 1             12           11       109.09      2      0   Bangladesh
# 2              7            2       350.00      0      1   Bangladesh
# 3              3            7        42.85      0      0     Pakistan
# 4            148          123       120.32     15      4     Pakistan
# ..           ...          ...          ...    ...    ...          ...
# 344           28           52        53.84      3      0  Afghanistan
# 345           56           61        91.80      3      2  West Indies
# 346           42           31       135.48      4      1      England
# 347           35           33       106.06      4      0   Bangladesh
# 349           50           72        69.44      1      1  New Zealand
#
#             ground       date  Year  not_out
# 0       Chattogram 2004-12-23  2004        0
# ...

# %%
opposition_lst = ['England','Australia','West Indies','South Africa','New Zealand','Pakistan','Sri Lanka','Bangladesh']
df_filtered = df_new[df_new['opposition'].isin(opposition_lst)]
df_boundries = df_filtered[['opposition','fours','sixes','runs_scored']].copy()
# df_boundries
df_boundries['runs_in_boundries']=(df_boundries['fours']*4 + df_boundries['sixes']*6)

df_selected = df_boundries[['opposition','runs_in_boundries','runs_scored']].copy()
grouped_by_opposition = df_selected.groupby('opposition')

df_boundries_grouped = grouped_by_opposition.sum().reset_index()


# # Create the bar plot
plt.figure(figsize=(10,6))
plt.bar(df_boundries_grouped['opposition'],df_boundries_grouped['runs_scored'], label='Category 1', color='orange')
plt.bar(df_boundries_grouped['opposition'],df_boundries_grouped['runs_in_boundries'] , bottom=df_boundries_grouped['runs_scored'], label='Category 2', color='r')

plt.grid(which='both', color='r', linestyle='-', linewidth=0.5)  # Major grid
plt.minorticks_on()  
plt.grid(which='minor', color='gray', linestyle=':', linewidth=0.5) 
# # Add titles and labels
plt.title('Stacked Bar Plot of Scores')
plt.xlabel('Opposition')
plt.ylabel('Runs Scored')


# # Show the plot
plt.show()

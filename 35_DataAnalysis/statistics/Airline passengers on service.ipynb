# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
airline_df = pd.read_csv('airline_dec_2008_50k.csv')
distance = airline_df['Distance']
# Out:
# <ipython-input-2-03d0de0a0d4f>:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   airline_df = pd.read_csv('airline_dec_2008_50k.csv')

# %%
mean_distance = distance.mean()
median_distance = distance.median()
Skewness_distance = distance.skew()

# %%
plt.figure(figsize=(8,6))
sns.histplot(distance, kde=True,color='skyblue',bins=30)
plt.axvline(mean_distance,color='red',ls='--',label=f'Mean: {mean_distance:.2f}')
plt.axvline(median_distance,color='black',ls='--',label=f'Median: {median_distance:.2f}')
plt.title(f"Distribution of Distance \n Skewness : {Skewness_distance:.2f}")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()
plt.show()

# %%
air_df = pd.read_csv('airline_passenger_satisfaction.csv')
air_df
Services = air_df['On-board Service']

# %%
mean_service = Services.mean()
median_service = Services.median()
Skewness_service = Services.skew()

# %%
plt.figure(figsize=(8,6))
sns.histplot(Services, kde=True,color='skyblue',bins=30)
plt.axvline(mean_service,color='red',ls='--',label=f'Mean: {mean_service:.2f}')
plt.axvline(median_service,color='black',ls='--',label=f'Median: {median_service:.2f}')
plt.title(f"Distribution of Distance \n Skewness : {Skewness_service:.2f}")
plt.xlabel("Services")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()
plt.show()
